# %% [markdown]
# # Predicting Turbofan Engine Remaining Useful Life: An ML Approach

# %% [markdown]
# ### 0.0 Problem Introduction and Objective
#
# The US Department of Defense has selected De Alwis ML Consulting Group to build it's predictive maintenance application, which is one of the DoD's National Mission Initiatives (NMIs). The goal is to build an application that can accurately predict turbofan engine failure.
#
# The DoD has listed some of its outcome goals for De Alwis ML Consulting Group:
# - reduce costs
# - enhance inventory managment and cash-flow managment
# - enhance mission readiness
# - save lives by reducing engine failure during high risk missions with life-threatenting consequences
# - disaster prevention
#
# **Prediction Goals**
#
# - Predict the probability a turbofan engine is likely to fail in its current state
# - Predict the remaining useful life (RUL) of each engine. RUL is equivalent of number of flights remained for the engine after the last datapoint in the test dataset.
#
# Hence we will need to build two models: a classifier with priobability score and a regression model to predict RUL.
#
# **De Alwis ML Consulting Group deliverables**
#
# - a front end web appliaction that allows the DoD to simulate and monitor turbofan engine failure predictions
# - a detailed summary of work including an executive summary of findings, reproducible data pipeline, extensive exploratory analysis, modelling assumptions, training and test set performance metrics.

# %% [markdown]
# ### 0.1 Datasets
#
# Kaggle description of the dataset is below:
#
# <div class="alert alert-info" role="alert">
#
# Engine degradation simulation was carried out using C-MAPSS. Four different were sets simulated under different combinations of operational conditions and fault modes. Records several sensor channels to characterize fault evolution. The data set was provided by the Prognostics CoE at NASA Ames.
#
# Data sets consists of multiple multivariate time series. Each data set is further divided into training and test subsets. Each time series is from a different engine i.e., the data can be considered to be from a fleet of engines of the same type. Each engine starts with different degrees of initial wear and manufacturing variation which is unknown to the user. This wear and variation is considered normal, i.e., it is not considered a fault condition. There are three operational settings that have a substantial effect on engine performance. These settings are also included in the data. The data is contaminated with sensor noise.
#
# The engine is operating normally at the start of each time series, and develops a fault at some point during the series. In the training set, the fault grows in magnitude until system failure. In the test set, the time series ends some time prior to system failure.
#
# </div>

# %% [markdown]
# The training set data contains a number of engines being run simultaneously until it fails. While the experiments were conducted till failure, all data till failure are not made public. Instead, data for an arbitrary number of cycles are provided for each engine of the test set. The task is then to predict after how many cycles each engine will fail. This predicted value is our remaining useful life (RUL).
#
# The training data does not contain the RUL values, but we can calculate them from the training data itself as it contains the run to failure data for each engine. Our assumption for training set RUL will use *linear-degredation*.

# %% [markdown]
# ### 0.3 Data Lineage
#
# Data lineage plays an important role in a machine learning workflow as it tracks data/meta data movements throughout your ML pipelines. Metadata is the “data about the data”, which includes various information about the data assets, such as the type, format, structure, author, date created, date modified and file size.
#
# Our data lineage path so far is as follows (will continue to track):
# - download data from NASA/Kaggle into 'raw' data folder in project scaffolding
# - push data to 'processed' folder after data pre-processing pipeline is applied (feature engineering, feature selection, etc.)

# %% [markdown]
# ### 1.0 Exploratory Data Analysis (EDA)
#
# Although there are four training and test set pairs, we will consider only FD001 for our exploratory analysis. However, we will make predictions against all four test sets at the modelling stage. In FD001, there are 100 turbofan engines (unit numbers) with 21 sensors and 3 settings. We assume each row in the dataset is a a snapshot in time during a cycle for the given engine.

# %% [markdown]
# #### 1.1 Load Data

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import seaborn as sns

# function to load any of the four training/test set pairs

def load_data(fleet: int):
    
    """
    Function that allows for creation of training/test set pairs for each of the four datasets provided. 
    
    Arguments: 
        fleet (int): 1,2,3 or 4 corresponding to the data sets FD001, FD002, FD003 and FD004, respectively 
    
    Returns: 
        pandas dataframes for each training and test set pair along with the RUL test set for each fleet
    """    
    
    valid_fleets = [1,2,3,4]
    
    if not valid_fleets:
        print("The only valid fleet numbers are 1,2,3,4")
    
    if fleet == 1: 
        index_names = ['unit_number', 'time_cycles']
        setting_names = ['setting_1', 'setting_2', 'setting_3']
        sensor_names = ['s_{}'.format(i+1) for i in range(0,21)]
        col_names = index_names + setting_names + sensor_names

        train_string = 'train_FD00' + str(fleet) + '.txt'
        test_string = 'test_FD00' + str(fleet) + '.txt'
        RUL_string = 'RUL_FD00' + str(fleet) + '.txt'
        
        train = pd.read_csv(train_string,sep='\s+',header=None,index_col=False,names=col_names)
        test = pd.read_csv(test_string,sep='\s+',header=None,index_col=False,names=col_names)
        y_test = pd.read_csv(RUL_string,sep='\s+',header=None,index_col=False,names=['RUL'])
        
    
    # add other fleets later
    if fleet == 2:
        None
    if fleet == 3:
        None
    if fleet == 4:
        None
    
    return train, test, y_test

# %%
# load data for FD001
train = load_data(1)[0]
test = load_data(1)[1]
rul = load_data(1)[2]

# %% [markdown]
# #### 1.2 Explore data types, dimensions and missing values

# %%
# a peak at the training data
train.sample(5)
# Out:
#        unit_number  time_cycles  setting_1  setting_2  setting_3     s_1  \
# 12679           64          199     0.0012     0.0000      100.0  518.67
# 15789           79           36    -0.0023     0.0003      100.0  518.67
# 16193           81           56     0.0028     0.0003      100.0  518.67
# 8130            42           89     0.0012    -0.0000      100.0  518.67
# 10708           54          179     0.0003     0.0003      100.0  518.67
#
#           s_2      s_3      s_4    s_5  ...    s_12     s_13     s_14    s_15  \
# 12679  642.86  1597.36  1410.54  14.62  ...  521.24  2388.13  8150.01  8.4608
# 15789  642.62  1580.53  1401.54  14.62  ...  522.13  2388.01  8139.01  8.4134
# 16193  642.93  1595.61  1399.05  14.62  ...  521.25  2388.09  8141.43  8.4082
# 8130   642.68  1585.22  1406.99  14.62  ...  522.14  2388.08  8139.30  8.4478
# 10708  642.59  1589.93  1403.59  14.62  ...  522.32  2388.03  8157.99  8.4589
#
#        s_16  s_17  s_18   s_19   s_20     s_21
# ...

# %%
# training, test dimensions
print(f"training set: {train.shape}, test shape: {test.shape}")
# Out:
# training set: (20631, 26), test shape: (13096, 26)

# %%
# unique engines
print(f"There are {len(train['unit_number'].unique())} unique engines in the training data, \
{len(test['unit_number'].unique())} in the test data and \
{len(rul)} in the RUL test data")
# Out:
# There are 100 unique engines in the training data, 100 in the test data and 100 in the RUL test data

# %%
# data types
train.dtypes
# Out:
# unit_number      int64
# time_cycles      int64
# setting_1      float64
# setting_2      float64
# setting_3      float64
# s_1            float64
# s_2            float64
# s_3            float64
# s_4            float64
# s_5            float64
# s_6            float64
# s_7            float64
# s_8            float64
# s_9            float64
# s_10           float64
# s_11           float64
# s_12           float64
# s_13           float64
# s_14           float64
# s_15           float64
# s_16           float64
# s_17             int64
# s_18             int64
# s_19           float64
# s_20           float64
# s_21           float64
# dtype: object

# %%
# cycles for each engine
print("Training set number of cycles for each engine:")
print("\n")
print(train.groupby('unit_number')['time_cycles'].count().values)
print("\n")
print("Test set number of cycles for each engine:")
print("\n")
print(test.groupby('unit_number')['time_cycles'].count().values)
print("\n")
print("True RUL number of cycles for each engine in test set:")
print("\n")
print(rul['RUL'].values)
# Out:
# Training set number of cycles for each engine:
#
#
# [192 287 179 189 269 188 259 150 201 222 240 170 163 180 207 209 276 195
#  158 234 195 202 168 147 230 199 156 165 163 194 234 191 200 195 181 158
#  170 194 128 188 216 196 207 192 158 256 214 231 215 198 213 213 195 257
#  193 275 137 147 231 172 185 180 174 283 153 202 313 199 362 137 208 213
#  213 166 229 210 154 231 199 185 240 214 293 267 188 278 178 213 217 154
#  135 341 155 258 283 336 202 156 185 200]
#
#
# Test set number of cycles for each engine:
#
#
# [ 31  49 126 106  98 105 160 166  55 192  83 217 195  46  76 113 165 133
#  135 184 148  39 130 186  48  76 140 158 171 143 196 145  50 203 198 126
#  121 125  37 133 123 156 172  54 152 146  73  78 303  74 144 189 164 121
#  113 136 160 176  94 147 159 232 155 168  71 147  71 187  54 152  68 131
#  112 137  88 205 162  72 101 133 213 162  73 172  34 110  56  68 177 146
#  234 150 244 133  89  97 134 121  97 198]
#
#
# ...

# %% [markdown]
# #### Missing value check
#
# - our datasets contain no missing values, we won't need to worry about that in our pre-processing pipeline

# %%
# training
train.isna().sum()
# Out:
# unit_number    0
# time_cycles    0
# setting_1      0
# setting_2      0
# setting_3      0
# s_1            0
# s_2            0
# s_3            0
# s_4            0
# s_5            0
# s_6            0
# s_7            0
# s_8            0
# s_9            0
# s_10           0
# s_11           0
# s_12           0
# s_13           0
# s_14           0
# s_15           0
# s_16           0
# s_17           0
# s_18           0
# s_19           0
# s_20           0
# s_21           0
# dtype: int64

# %%
test.isna().sum()
# Out:
# unit_number    0
# time_cycles    0
# setting_1      0
# setting_2      0
# setting_3      0
# s_1            0
# s_2            0
# s_3            0
# s_4            0
# s_5            0
# s_6            0
# s_7            0
# s_8            0
# s_9            0
# s_10           0
# s_11           0
# s_12           0
# s_13           0
# s_14           0
# s_15           0
# s_16           0
# s_17           0
# s_18           0
# s_19           0
# s_20           0
# s_21           0
# dtype: int64

# %%
# target test
rul.isna().sum()
# Out:
# RUL    0
# dtype: int64

# %% [markdown]
# #### 1.3 Summary and descriptive statistics
#
# - the settings features have very low variance, we will likely not need them for modelling with target (RUL)
# - a number of sensors also have very low variance, we will need to look into these further to determine if we keep them in the feature selection stage of our pre-processing pipeline

# %%
train.describe().transpose()
# Out:
#                count         mean           std        min        25%  \
# unit_number  20631.0    51.506568  2.922763e+01     1.0000    26.0000
# time_cycles  20631.0   108.807862  6.888099e+01     1.0000    52.0000
# setting_1    20631.0    -0.000009  2.187313e-03    -0.0087    -0.0015
# setting_2    20631.0     0.000002  2.930621e-04    -0.0006    -0.0002
# setting_3    20631.0   100.000000  0.000000e+00   100.0000   100.0000
# s_1          20631.0   518.670000  0.000000e+00   518.6700   518.6700
# s_2          20631.0   642.680934  5.000533e-01   641.2100   642.3250
# s_3          20631.0  1590.523119  6.131150e+00  1571.0400  1586.2600
# s_4          20631.0  1408.933782  9.000605e+00  1382.2500  1402.3600
# s_5          20631.0    14.620000  1.776400e-15    14.6200    14.6200
# s_6          20631.0    21.609803  1.388985e-03    21.6000    21.6100
# s_7          20631.0   553.367711  8.850923e-01   549.8500   552.8100
# ...

# %% [markdown]
# #### 1.4 Data distributions

# %% [markdown]
# #### 1.4.1 Boxplot
#
# - sensors 1,5,6,10,16,18 and 19 are constants and will not be useful for modelling
# - some sensors (e.g. 3,8,9,14) have quite of few outliers that we may need to deal with during pre-processing

# %%
import matplotlib.pyplot as plt

# melt down the dataframe to use with FacetGrid for box-plots
sensor_cols = train.iloc[:, np.r_[0, 5:26]]

melted = pd.melt(sensor_cols, id_vars=['unit_number'], value_vars=sensor_cols.iloc[:,1:22], \
       var_name='sensor', value_name='reading')

t = melted[['sensor','reading']]
g = sns.FacetGrid(t, col="sensor", col_wrap=3, sharex=False)
g.map_dataframe(sns.boxplot, "reading");

# %% [markdown]
# #### 1.4.2 Histograms
#
# - some sensors appear to have approximately Guassian distributions but others are skewed or multi-modal
# - likely will need a scaling solution and possibly a transformation to bring skewed distributions to more Guassian

# %%
g = sns.FacetGrid(t, col="sensor", col_wrap=3, sharey=False, sharex=False)
g.map_dataframe(sns.kdeplot, "reading");

# %% [markdown]
# Let's now calculate our target feature (RUL) in our training data.

# %%
# function to create Remaining Useful life column in training data
def rul_func(df):    
    return df.groupby('unit_number')['time_cycles'].max()

temp = pd.DataFrame(rul_func(train)).reset_index()
train = train.merge(temp, left_on='unit_number', right_on='unit_number')  
train['RUL']=train['time_cycles_y']-train['time_cycles_x']

# %%
# drop time_cyles_y 
train.drop(columns=['time_cycles_y'], inplace=True)

# %%
# rename time_cycle_x to original
train = train.rename(columns={'time_cycles_x': 'time_cycles'})

# %%
train.head()
# Out:
#    unit_number  time_cycles  setting_1  setting_2  setting_3     s_1     s_2  \
# 0            1            1    -0.0007    -0.0004      100.0  518.67  641.82
# 1            1            2     0.0019    -0.0003      100.0  518.67  642.15
# 2            1            3    -0.0043     0.0003      100.0  518.67  642.35
# 3            1            4     0.0007     0.0000      100.0  518.67  642.35
# 4            1            5    -0.0019    -0.0002      100.0  518.67  642.37
#
#        s_3      s_4    s_5  ...     s_13     s_14    s_15  s_16  s_17  s_18  \
# 0  1589.70  1400.60  14.62  ...  2388.02  8138.62  8.4195  0.03   392  2388
# 1  1591.82  1403.14  14.62  ...  2388.07  8131.49  8.4318  0.03   392  2388
# 2  1587.99  1404.20  14.62  ...  2388.03  8133.23  8.4178  0.03   390  2388
# 3  1582.79  1401.87  14.62  ...  2388.08  8133.83  8.3682  0.03   392  2388
# 4  1582.85  1406.22  14.62  ...  2388.04  8133.80  8.4294  0.03   393  2388
#
#     s_19   s_20     s_21  RUL
# ...

# %%
# max cycles
train.groupby('unit_number').max().reset_index().head(5)
# Out:
#    unit_number  time_cycles  setting_1  setting_2  setting_3     s_1     s_2  \
# 0            1          192     0.0047     0.0005      100.0  518.67  644.21
# 1            2          287     0.0076     0.0006      100.0  518.67  643.94
# 2            3          179     0.0058     0.0005      100.0  518.67  643.93
# 3            4          189     0.0059     0.0006      100.0  518.67  644.53
# 4            5          269     0.0055     0.0005      100.0  518.67  644.02
#
#        s_3      s_4    s_5  ...     s_13     s_14    s_15  s_16  s_17  s_18  \
# 0  1605.44  1432.52  14.62  ...  2388.35  8140.58  8.5227  0.03   398  2388
# 1  1610.10  1431.17  14.62  ...  2388.26  8175.57  8.5377  0.03   398  2388
# 2  1606.50  1438.51  14.62  ...  2388.20  8255.34  8.5363  0.03   399  2388
# 3  1612.11  1434.12  14.62  ...  2388.17  8259.42  8.5462  0.03   399  2388
# 4  1609.41  1434.59  14.62  ...  2388.23  8215.19  8.5410  0.03   398  2388
#
#     s_19   s_20     s_21  RUL
# ...

# %%
# distribution of RUL in training data
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
sns.boxplot(x='RUL', data=train, ax=ax[0])
sns.kdeplot(x='RUL', data=train, ax=ax[1]);

# %% [markdown]
# - our target feature (RUL) has a skewed distribution and quite a few outliers that we will look at in the pre-processing stage more carefully

# %% [markdown]
# #### 1.5 Correlation Analysis
#
# - RUL is highly positively correlated with a number of sensors (2,3,4,8,13,15,17) and lightly negatively correlated with the others
# - Many sensors are strongly correlated with each other (both positively and negatively). We may need to address this by reducing the features

# %%
train.iloc[:, np.r_[26,6:9]]
# Out:
#        RUL     s_2      s_3      s_4
# 0      191  641.82  1589.70  1400.60
# 1      190  642.15  1591.82  1403.14
# 2      189  642.35  1587.99  1404.20
# 3      188  642.35  1582.79  1401.87
# 4      187  642.37  1582.85  1406.22
# ...    ...     ...      ...      ...
# 20626    4  643.49  1597.98  1428.63
# 20627    3  643.54  1604.50  1433.58
# 20628    2  643.42  1602.46  1428.18
# 20629    1  643.23  1605.26  1426.53
# 20630    0  643.85  1600.38  1432.14
#
# [20631 rows x 4 columns]

# %%
# 1 5 6 10 16 18 19
train_corr = train.iloc[:, np.r_[26,6:9,11:14,15:20,21,24:26]].corr()
train_corr
# Out:
#            RUL       s_2       s_3       s_4       s_7       s_8       s_9  \
# RUL   1.000000 -0.606484 -0.584520 -0.678948  0.657223 -0.563968 -0.390102
# s_2  -0.606484  1.000000  0.602610  0.714949 -0.702136  0.662325  0.273764
# s_3  -0.584520  0.602610  1.000000  0.678413 -0.664595  0.602481  0.322964
# s_4  -0.678948  0.714949  0.678413  1.000000 -0.793130  0.746852  0.297429
# s_7   0.657223 -0.702136 -0.664595 -0.793130  1.000000 -0.767132 -0.217835
# s_8  -0.563968  0.662325  0.602481  0.746852 -0.767132  1.000000 -0.032091
# s_9  -0.390102  0.273764  0.322964  0.297429 -0.217835 -0.032091  1.000000
# s_11 -0.696228  0.740020  0.695900  0.830136 -0.822805  0.782213  0.274591
# s_12  0.671983 -0.724578 -0.680307 -0.815591  0.812713 -0.786540 -0.210238
# s_13 -0.562569  0.661792  0.600963  0.745158 -0.764611  0.826084 -0.034763
# s_14 -0.306769  0.179752  0.237137  0.190748 -0.110053 -0.144787  0.963157
# ...

# %%
# heatmap
mask = np.triu(np.ones_like(train_corr, dtype=bool))
f, ax = plt.subplots(figsize=(10, 10))
cmap = sns.diverging_palette(120, 5, as_cmap=True)
sns.heatmap(train_corr, mask=mask, cmap=cmap, vmax=.3, center=0,square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %% [markdown]
# #### 1.6 Degredation method: Linear vs Non-Linear

# %%
# facet over the units

# melt sensors into one column
subset = train.iloc[:, np.r_[0,1,26,6:9,11:14,15:20,21,24:26]]
melted = pd.melt(subset, id_vars = subset.iloc[:,0:3], value_vars=subset.iloc[:,3:], 
                 var_name='sensor', value_name='reading')

# %%
def sensorFacetPlot(df, sensor):
    
    t = df[df['sensor']==sensor]
    g = sns.FacetGrid(t, col="unit_number", col_wrap=5, sharex=False, sharey=False)
    g.map_dataframe(sns.scatterplot, x="reading", y="RUL")

# %% [markdown]
# Lets sample a few units to see the relationship between the sensor reading and the RUL

# %%
subset.columns[3:]
# Out:
# Index(['s_2', 's_3', 's_4', 's_7', 's_8', 's_9', 's_11', 's_12', 's_13',
#        's_14', 's_15', 's_17', 's_20', 's_21'],
#       dtype='object')

# %%
sensorFacetPlot(melted, "s_15")

# %% [markdown]
# Notes:
#
# - Consider adding polynomial regression and quadratic features.
# - Sensor 17 is not continous, we should considering binning it.
# - Sensors 20 and 21 has a quadratic relationship when sensor readings get between 23.2 and 23.4. Sensors 20 and 21 are positively related to RUl, higher readings mean longer RUL.

# %% [markdown]
# ### 2.0 Data Pre-Processing, Feature Engineering and Feature Selection
#
# We will start to build our pre-processing pipeline here. A few items to consider:
#
# - first run TPOT to see if we can get a useable pipeline template
# - we have no missing values to deal with
# - outliers appear to be a concern for many sensors
# - distributions show many sensors are non-normally distributed
# - likely need a scaling solution

# %% [markdown]
# #### 2.1 Automated Pipeline with TPOT (Tree-based Pipeline Optimization Tool)

# %%
import tpot
from tpot import TPOTRegressor
from sklearn.model_selection import RepeatedKFold

# cross-val
cv = RepeatedKFold(n_splits=5, n_repeats=3, random_state=1)

# instatiate regressor
model = TPOTRegressor(generations=35, 
                      population_size=50, scoring='neg_mean_squared_error', 
                      cv=cv, verbosity=2, random_state=1, n_jobs=-1)

# %%
#fitted = model.fit(X_train, y_train)
#fitted

# %%
#fitted.export('tpot_export.py')

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import LassoLarsCV, RidgeCV, SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline, make_union
from sklearn.tree import DecisionTreeRegressor
from tpot.builtins import StackingEstimator
from tpot.export_utils import set_param_recursive
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from feature_engine.selection import DropFeatures
from sklearn.model_selection import RandomizedSearchCV
from sklearn.compose import TransformedTargetRegressor
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.utils.fixes import loguniform
from sklearn.compose import TransformedTargetRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
# pipeline generated by TPOT
tpot_pipeline = make_pipeline(
    StackingEstimator(estimator=SGDRegressor(alpha=0.0, eta0=0.01, fit_intercept=False, l1_ratio=0.0, learning_rate="invscaling", loss="huber", penalty="elasticnet", power_t=50.0)),
    StackingEstimator(estimator=RidgeCV()),
    StackingEstimator(estimator=DecisionTreeRegressor(max_depth=3, min_samples_leaf=10, min_samples_split=3)),
    StackingEstimator(estimator=LassoLarsCV(normalize=False)),
    ExtraTreesRegressor(bootstrap=False, max_features=0.7500000000000001, min_samples_leaf=19, min_samples_split=16, n_estimators=100)
)

# %% [markdown]
# - Note that TPOT did not scale the features in the pipeline, reduce the feature set, or perform any pre-processing tasks.

# %% [markdown]
# For the purposes of feature scaling, feature engineering and selection we will use the training data provided, but split it into training and test sets.

# %%
X = train.drop(columns='RUL', axis=1)
y = train.pop('RUL')

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((16504, 26), (4127, 26), (16504,), (4127,))

# %% [markdown]
# #### 2.2 Feature Scaling
#
# Given that are sensors have a wide distributional range, outliers and non-Guassian distributions in many cases, we will use feature scaling to address these problems, namely, standardization or normalization. Quick check below to see if it helps with our training.

# %%
from sklearn.svm import SVR
# instantiate
lr = SVR(kernel='linear')
ss = StandardScaler()
mm = MinMaxScaler()

# %% [markdown]
# SVR without any scaling:

# %%
# baseline model (no scaling)
lr_fit = lr.fit(X_train, y_train)
lr_predict = lr_fit.predict(X_test)

# %%
# baseline (no scaling)
round(mean_absolute_error(lr_predict, y_test),1), round(mean_squared_error(lr_predict, y_test)**0.5,1)
# Out:
# (35.4, 45.3)

# %% [markdown]
# SVR with standardization:

# %%
ss.fit(X_train);

# %%
X_train_scaled = ss.transform(X_train)
X_test_scaled = ss.transform(X_test)

# %%
X_train_scaled.shape, X_test_scaled.shape
# Out:
# ((16504, 26), (4127, 26))

# %%
lr_ss = lr.fit(X_train_scaled, y_train)

# %%
lr_predict_ss = lr_ss.predict(X_test_scaled)

# %%
# standard scaler
round(mean_absolute_error(lr_predict_ss, y_test),1), round(mean_squared_error(lr_predict_ss, y_test)**0.5,1)
# Out:
# (29.7, 39.5)

# %% [markdown]
# SVR with MinMax scaler:

# %%
mm.fit(X_train);

# %%
X_train_scaled = mm.transform(X_train)
X_test_scaled = mm.transform(X_test)

# %%
X_train_scaled.shape, X_test_scaled.shape
# Out:
# ((16504, 26), (4127, 26))

# %%
lr_mm = lr.fit(X_train_scaled, y_train)

# %%
lr_predict_mm = lr_mm.predict(X_test_scaled)

# %%
# standard scaler
round(mean_absolute_error(lr_predict_mm, y_test),1), round(mean_squared_error(lr_predict_mm, y_test)**0.5,1)
# Out:
# (29.7, 39.8)

# %% [markdown]
# - On the surface it appears that scaling may be useful so we will build it into our pre-processing pipeline

# %% [markdown]
# #### 2.3 Feature Engineering: Adding polynomial features
#
# From our exploratory data analysis, we saw that the RUL has a non-linear relationship with most of the sensors, a quadratic shape look most suitable. We will include a quadratic feature for each sensor in our pipeline.

# %% [markdown]
# #### 2.4 Feature Selection
#
# We won't need the below features, so we will drop them in our pipeline.

# %%
drop_list = ['unit_number', 'time_cycles', 'setting_1', 'setting_2', 'setting_3', 
             's_1', 's_5', 's_6', 's_10', 's_16', 's_18', 's_19']

# %% [markdown]
# #### 2.5 Preprocessing Pipeline

# %%
# create pre-processing pipeline for feature selection and engineering

preprocessing_pipeline = make_pipeline(DropFeatures(features_to_drop=drop_list),
                                       PolynomialFeatures(2),
                                       MinMaxScaler()
                                    )

# %%
preprocessing_pipeline
# Out:
# Pipeline(steps=[('dropfeatures',
#                  DropFeatures(features_to_drop=['unit_number', 'time_cycles',
#                                                 'setting_1', 'setting_2',
#                                                 'setting_3', 's_1', 's_5',
#                                                 's_6', 's_10', 's_16', 's_18',
#                                                 's_19'])),
#                 ('polynomialfeatures', PolynomialFeatures()),
#                 ('minmaxscaler', MinMaxScaler())])

# %% [markdown]
# ### 3.0 Modelling: Baseline Model, Iterating Standard ML Models and Deep Learning Approach
#
# Creating a baseline model from which to compare successively more complex models serves as number of purposes, we list a few below:
#
# - gives us a relative accuracy metric in which to compare more complex models
# - can help us identify changes to our pre-processing pipeline (e.g. scaling method)
# - faster model iteration (e.g. abandon models that perform worse than our baseline or perhaps not much better)
# - understanding the predictive capability of our training data
#
# We will take a first try with the following models:
# - Linear regression as a baseline
# - Linear regression with regularization: Ridge (L2) & Lasso (L1)
# - Support Vector Regression (SVR)
# - Random Forest Regression (RFR)
# - XGBoost Regression
# - TPOT Ensemble model from above
# - After the standard machine learning approach, we will explore deep learning networks.

# %%
# performance metric evaluator function
def evaluate(y_true, y_hat, label='test'):
    mae = mean_absolute_error(y_true, y_hat)
    mse = mean_squared_error(y_true, y_hat)
    rmse = np.sqrt(mse)
    
    print(f"Results for the {label} set:\n")
    print(f"MAE:{round(mae,2)} MSE:{round(mse,2)} RMSE:{round(rmse,2)}")

# %% [markdown]
# #### 3.1 Training, Validation, Test Split

# %%
# training data
X_train = X
y_train = y

# test data 
X_test = test.groupby('unit_number').last().reset_index()
y_test = rul

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((20631, 26), (20631,), (100, 26), (100, 1))

# %%
# helper function for modelling

def output(model, model_name, params):
    
    pipeline = make_pipeline(preprocessing_pipeline, model)
    
    grid_search = RandomizedSearchCV(pipeline, 
                                     param_distributions=params,
                                     cv=5,
                                     scoring='neg_root_mean_squared_error')
    
    # fit to training data
    fitted = grid_search.fit(X_train,y_train)
    
    # best estimator
    best_est = grid_search.best_estimator_
    
    # training predictions
    train_pred = best_est.predict(X_train)
    
    # test predictions
    test_pred = best_est.predict(X_test)
    
    return model_name, fitted, best_est, train_pred, test_pred

# %%
def resultPlot(train_pred, train_y, test_pred, test_y):
    
    fig, ax = plt.subplots(1, 2, figsize=(12, 4))
    sns.regplot(x=train_pred, y=train_y, ax=ax[0])
    ax[0].set_title('Training Data')
    ax[0].set(ylabel='Training RUL')
    ax[0].set(xlabel='Predicted Training RUL')
    
    sns.regplot(x=test_pred, y=test_y, ax=ax[1])
    ax[1].set_title('Test Data')
    ax[1].set(ylabel='Test RUL')
    ax[1].set(xlabel='Predicted Test RUL')

# %% [markdown]
# #### 3.3 Baseline Model: Linear Regression

# %%
model = LinearRegression()
model_name = 'Linear Regression'

# %%
list(make_pipeline(preprocessing_pipeline, model).get_params().items())[20:24]
# Out:
# [('linearregression__fit_intercept', True),
#  ('linearregression__n_jobs', None),
#  ('linearregression__normalize', 'deprecated'),
#  ('linearregression__positive', False)]

# %%
params = {'linearregression__fit_intercept': [True,False]}

# %%
lr = output(model, model_name, params)

# %%
evaluate(y_true=y_train, y_hat=lr[3], label='train')
# Out:
# Results for the train set:
#
# MAE:30.81 MSE:1771.81 RMSE:42.09

# %%
evaluate(y_true=y_test, y_hat=lr[4], label='test')
# Out:
# Results for the test set:
#
# MAE:24.03 MSE:981.59 RMSE:31.33

# %%
resultPlot(lr[3], y_train, lr[4], y_test)

# %% [markdown]
# #### Ridge Regression (L2)

# %%
model = Ridge()
model_name = 'Ridge Regression'

# %%
len(list(make_pipeline(preprocessing_pipeline, model).get_params().items()))
# Out:
# 28

# %%
list(make_pipeline(preprocessing_pipeline, model).get_params().items())[19:28]
# Out:
# [('ridge__alpha', 1.0),
#  ('ridge__copy_X', True),
#  ('ridge__fit_intercept', True),
#  ('ridge__max_iter', None),
#  ('ridge__normalize', 'deprecated'),
#  ('ridge__positive', False),
#  ('ridge__random_state', None),
#  ('ridge__solver', 'auto'),
#  ('ridge__tol', 0.001)]

# %%
params = {'ridge__fit_intercept': [True,False], 'ridge__alpha': loguniform(1e-4, 1e0)}

# %%
rr = output(model, model_name, params)

# %%
evaluate(y_true=y_train, y_hat=rr[3], label='train')
# Out:
# Results for the train set:
#
# MAE:30.86 MSE:1778.26 RMSE:42.17

# %%
evaluate(y_true=y_test, y_hat=rr[4], label='test')
# Out:
# Results for the test set:
#
# MAE:23.86 MSE:970.3 RMSE:31.15

# %%
resultPlot(rr[3], y_train, rr[4], y_test)

# %% [markdown]
# #### Lasso Regression (L2)

# %%
model = Lasso()
model_name = 'Lasso Regression'

# %%
len(list(make_pipeline(preprocessing_pipeline, model).get_params().items()))
# Out:
# 30

# %%
list(make_pipeline(preprocessing_pipeline, model).get_params().items())[19:30]
# Out:
# [('lasso__alpha', 1.0),
#  ('lasso__copy_X', True),
#  ('lasso__fit_intercept', True),
#  ('lasso__max_iter', 1000),
#  ('lasso__normalize', 'deprecated'),
#  ('lasso__positive', False),
#  ('lasso__precompute', False),
#  ('lasso__random_state', None),
#  ('lasso__selection', 'cyclic'),
#  ('lasso__tol', 0.0001),
#  ('lasso__warm_start', False)]

# %%
params = {'lasso__fit_intercept': [True,False], 'lasso__alpha': loguniform(1e-4, 1e0)}

# %%
la_r = output(model, model_name, params)

# %%
evaluate(y_true=y_train, y_hat=la_r[3], label='train')
# Out:
# Results for the train set:
#
# MAE:33.94 MSE:1980.87 RMSE:44.51

# %%
evaluate(y_true=y_test, y_hat=la_r[4], label='test')
# Out:
# Results for the test set:
#
# MAE:25.43 MSE:1015.76 RMSE:31.87

# %%
resultPlot(la_r[3], y_train, la_r[4], y_test)

# %% [markdown]
# #### Support Vector Regression

# %%
model = SVR()
model_name = 'SVR'

# %%
len(list(make_pipeline(preprocessing_pipeline, model).get_params().items()))
# Out:
# 30

# %%
list(make_pipeline(preprocessing_pipeline, model).get_params().items())[19:30]
# Out:
# [('svr__C', 1.0),
#  ('svr__cache_size', 200),
#  ('svr__coef0', 0.0),
#  ('svr__degree', 3),
#  ('svr__epsilon', 0.1),
#  ('svr__gamma', 'scale'),
#  ('svr__kernel', 'rbf'),
#  ('svr__max_iter', -1),
#  ('svr__shrinking', True),
#  ('svr__tol', 0.001),
#  ('svr__verbose', False)]

# %%
params = {'svr__C': [0.1, 0.25, 0.50, 1.0], 
          'svr__epsilon': [0.4, 0.3, 0.2, 0.1, 0.05],
          'svr__kernel': ['rbf', 'linear']         
         }

# %%
svr = output(model, model_name, params)

# %%
evaluate(y_true=y_train, y_hat=svr[3], label='train')
# Out:
# Results for the train set:
#
# MAE:29.55 MSE:1798.65 RMSE:42.41

# %%
evaluate(y_true=y_test, y_hat=svr[4], label='test')
# Out:
# Results for the test set:
#
# MAE:18.64 MSE:690.64 RMSE:26.28

# %%
resultPlot(svr[3], y_train, svr[4], y_test)

# %% [markdown]
# #### Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model_name = 'RFR'

# %%
len(list(make_pipeline(preprocessing_pipeline, model).get_params().items()))
# Out:
# 36

# %%
list(make_pipeline(preprocessing_pipeline, model).get_params().items())[19:36]
# Out:
# [('randomforestregressor__bootstrap', True),
#  ('randomforestregressor__ccp_alpha', 0.0),
#  ('randomforestregressor__criterion', 'squared_error'),
#  ('randomforestregressor__max_depth', None),
#  ('randomforestregressor__max_features', 1.0),
#  ('randomforestregressor__max_leaf_nodes', None),
#  ('randomforestregressor__max_samples', None),
#  ('randomforestregressor__min_impurity_decrease', 0.0),
#  ('randomforestregressor__min_samples_leaf', 1),
#  ('randomforestregressor__min_samples_split', 2),
#  ('randomforestregressor__min_weight_fraction_leaf', 0.0),
#  ('randomforestregressor__n_estimators', 100),
#  ('randomforestregressor__n_jobs', None),
#  ('randomforestregressor__oob_score', False),
#  ('randomforestregressor__random_state', None),
#  ('randomforestregressor__verbose', 0),
#  ('randomforestregressor__warm_start', False)]

# %%
params = {'randomforestregressor__n_estimators': [100]}

# %%
#rfr = output(model, model_name, params)

# %%
#evaluate(y_true=y_train, y_hat=rfr[3], label='train')

# %%
#evaluate(y_true=y_test, y_hat=rfr[4], label='test')

# %%
#resultPlot(rfr[3], y_train, rfr[4], y_test)

# %% [markdown]
# #### XGBoost Regressor

# %%
from xgboost import XGBRegressor
model = XGBRegressor()
model_name = 'XGB'

# %%
model.get_params()
# Out:
# {'objective': 'reg:squarederror',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'gpu_id': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'predictor': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
# ...

# %%
params = {'xgbregressor__learning_rate': [0.001, 0.001, 0.01]}

# %%
xgb = output(model, model_name, params)

# %%
evaluate(y_true=y_train, y_hat=xgb[3], label='train')
# Out:
# Results for the train set:
#
# MAE:42.51 MSE:3618.02 RMSE:60.15

# %%
evaluate(y_true=y_test, y_hat=xgb[4], label='test')
# Out:
# Results for the test set:
#
# MAE:19.34 MSE:616.37 RMSE:24.83

# %%
resultPlot(xgb[3], y_train, xgb[4], y_test)

# %% [markdown]
# #### TPOT model
#
# Recall our TPOT pipeline produced earlier, with optimized hyperparameters.

# %%
tpot_pipeline
# Out:
# Pipeline(steps=[('stackingestimator-1',
#                  StackingEstimator(estimator=SGDRegressor(alpha=0.0,
#                                                           fit_intercept=False,
#                                                           l1_ratio=0.0,
#                                                           loss='huber',
#                                                           penalty='elasticnet',
#                                                           power_t=50.0))),
#                 ('stackingestimator-2', StackingEstimator(estimator=RidgeCV())),
#                 ('stackingestimator-3',
#                  StackingEstimator(estimator=DecisionTreeRegressor(max_depth=3,
#                                                                    min_samples_leaf=10,
#                                                                    min_samples_split=3))),
#                 ('stackingestimator-4',
# ...

# %%
fitted = tpot_pipeline.fit(X_train, y_train)

# %%
predicted_train = fitted.predict(X_train)
predicted_test = fitted.predict(X_test)

# %% [markdown]
# Training results:

# %%
print("MAE:", round(mean_absolute_error(predicted_train, y_train),2)),
print("MSE:", round(mean_squared_error(predicted_train, y_train),2)), 
print("RMSE:", round(mean_squared_error(predicted_train, y_train)**0.5,2))
# Out:
# MAE: 20.23
# MSE: 827.25
# RMSE: 28.76

# %% [markdown]
# Test results:

# %%
print("MAE:", round(mean_absolute_error(predicted_test, y_test),2)),
print("MSE:", round(mean_squared_error(predicted_test, y_test),2)), 
print("RMSE:", round(mean_squared_error(predicted_test, y_test)**0.5,2))
# Out:
# MAE: 19.91
# MSE: 745.28
# RMSE: 27.3

# %% [markdown]
# Let's try to wrap it into our preprocessing pipeline:

# %%
tpot_pipeline_2 = make_pipeline(preprocessing_pipeline, tpot_pipeline)

# %%
fitted_2 = tpot_pipeline_2.fit(X_train, y_train)

# %%
predicted_train_2 = fitted_2.predict(X_train)
predicted_test_2 = fitted_2.predict(X_test)

# %%
print("MAE:", round(mean_absolute_error(predicted_train_2, y_train),2)),
print("MSE:", round(mean_squared_error(predicted_train_2, y_train),2)), 
print("RMSE:", round(mean_squared_error(predicted_train_2, y_train)**0.5,2))
# Out:
# MAE: 24.34
# MSE: 1194.82
# RMSE: 34.57

# %%
print("MAE:", round(mean_absolute_error(predicted_test_2, y_test),2)),
print("MSE:", round(mean_squared_error(predicted_test_2, y_test),2)), 
print("RMSE:", round(mean_squared_error(predicted_test_2, y_test)**0.5,2))
# Out:
# MAE: 23.16
# MSE: 1053.26
# RMSE: 32.45
